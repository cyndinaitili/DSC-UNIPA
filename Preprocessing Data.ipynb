# %%
#Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Import Dataset
#Loading Dataset
dataset = pd.read_csv (r'E:/DSC/energydata_complete.csv')
print (dataset)
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
dataset.shape
# Out:
# (19735, 29)

# %%
#Viewing dataset
dataset.sample(19735)
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 16453  2016-05-04 23:10:00          50       0  23.200000  34.400000
# 11072  2016-03-28 14:20:00         290      10  23.166667  38.966667
# 15891  2016-05-01 01:30:00          50       0  20.963333  37.900000
# 10698  2016-03-26 00:00:00          70       0  23.000000  38.590000
# 4063   2016-02-08 22:10:00          70      30  23.600000  40.860000
# ...                    ...         ...     ...        ...        ...
# 17195  2016-05-10 02:50:00          50       0  25.100000  43.700000
# 10851  2016-03-27 01:30:00          60       0  22.890000  40.626667
# 4886   2016-02-14 15:20:00         110      10  21.500000  40.590000
# 3388   2016-02-04 05:40:00          50       0  21.100000  42.090000
# 2229   2016-01-27 04:30:00          40       0  20.390000  44.290000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
#Classifying the dependent and Independent Variables
X = dataset.iloc[:,:-1].values #Takes all rows of all columns except the last column
print(X)
# Out:
# [['2016-01-11 17:00:00' 60 30 ... 63.0 5.3 13.275433157104999]
#  ['2016-01-11 17:10:00' 60 30 ... 59.1666666666667 5.2 18.606194981839508]
#  ['2016-01-11 17:20:00' 50 30 ... 55.3333333333333 5.1 28.64266816759482]
#  ...
#  ['2016-05-27 17:40:00' 270 10 ... 25.3333333333333 13.266666666666698
#   29.19911708449945]
#  ['2016-05-27 17:50:00' 420 10 ... 26.166666666666693 13.233333333333302
#   6.322783650830388]
#  ['2016-05-27 18:00:00' 430 10 ... 27.0 13.2 34.11885058740153]]

# %%
Y = dataset.iloc[:,-1].values # Takes all rows of the last column
print(Y)
# Out:
# [13.27543316 18.60619498 28.64266817 ... 29.19911708  6.32278365
#  34.11885059]

# %%
#the below code counts the number of missing values in each column
dataset.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer()
imputed_numerical = imputer.fit_transform(dataset.select_dtypes(exclude=['object']))
imputed_numerical = pd.DataFrame(imputed_numerical, columns=dataset.select_dtypes(exclude=['object']).columns)
imputed_numerical.isna().sum()
# Out:
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
imputer = SimpleImputer(strategy="most_frequent")
imputed_categorical = imputer.fit_transform(dataset.select_dtypes(include=['object']))
imputed_categorical = pd.DataFrame(imputed_categorical, columns = dataset.select_dtypes(include=['object']).columns)
imputed_categorical.isna().sum()
# Out:
# date    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_X
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
X_test
# Out:
# array([[-0.79359516, -0.36722927, -0.4768775 , ...,  2.01314368,
#         -1.34974784,  0.46653722],
#        [-1.68375314,  0.51355565,  2.04158444, ..., -0.78534106,
#         -0.56257693, -1.11203382],
#        [-1.64347529, -0.07363429,  0.78235347, ..., -0.00798418,
#         -0.79316235, -1.57116662],
#        ...,
#        [-0.94239453, -0.46509426, -0.4768775 , ..., -1.25175518,
#         -0.53872327,  1.000155  ],
#        [ 1.38193618, -0.17149928, -0.4768775 , ..., -0.95494619,
#          1.25030152, -1.20058367],
#        [-0.76967469, -0.17149928, -0.4768775 , ...,  0.33122609,
#         -0.75738185,  0.38803773]])

# %%
#DATA ANALYSYS

# %%
import pandas
data = 'E:/DSC/energydata_complete.csv'
names = ['date','Appliances','lights','T1','RH_1','T2','RH_2','T3','RH_3','T4','RH_4','T5','RH_5','T6','RH_6','T7','RH_7','T8','RH_8','T9','RH_9','T_out','Press_mm_hg','RH_out','Windspeed','Visibility','Tdewpoint','rv1','rv2']
dataset = pandas.read_csv(data, names = names)

# %%
print(dataset.shape)
# Out:
# (19736, 29)

# %%
print(dataset.head(20))
# Out:
#                    date  Appliances  lights                  T1  \
# 0                  date  Appliances  lights                  T1
# 1   2016-01-11 17:00:00          60      30  19.890000000000001
# 2   2016-01-11 17:10:00          60      30  19.890000000000001
# 3   2016-01-11 17:20:00          50      30  19.890000000000001
# 4   2016-01-11 17:30:00          50      40  19.890000000000001
# 5   2016-01-11 17:40:00          60      40  19.890000000000001
# 6   2016-01-11 17:50:00          50      40  19.890000000000001
# 7   2016-01-11 18:00:00          60      50  19.890000000000001
# 8   2016-01-11 18:10:00          60      50  19.856666666666701
# 9   2016-01-11 18:20:00          60      40  19.789999999999999
# 10  2016-01-11 18:30:00          70      40  19.856666666666701
# 11  2016-01-11 18:40:00         230      70  19.926666666666701
# 12  2016-01-11 18:50:00         580      60  20.066666666666698
# 13  2016-01-11 19:00:00         430      50  20.133333333333301
# ...

# %%
print(dataset.describe()) #The above command gives you the following output that shows the statistical summary of each attribute −
# Out:
#                        date Appliances lights                  T1  \
# count                 19736      19736  19736               19736
# unique                19736         93      9                 723
# top     2016-03-21 12:30:00         50      0  21.000000000000000
# freq                      1       4368  15252                 514
#
#                       RH_1                  T2                RH_2  \
# count                19736               19736               19736
# unique                2548                1651                3377
# top     39.090000000000003  19.199999999999999  40.000000000000000
# freq                   152                 331                 135
#
#                         T3                RH_3                  T4  ...  \
# count                19736               19736               19736  ...
# unique                1427                2619                1391  ...
# top     22.390000000000001  37.590000000000003  20.390000000000001  ...
# ...
